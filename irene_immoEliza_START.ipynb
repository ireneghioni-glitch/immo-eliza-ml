# %% [markdown]
# <h1 style="color:#c8a2c8; font-weight:bold; margin-bottom: 0px; padding-bottom: 0px;">ImmoEliza Project</h1>
# <h2 style="color:#c8a2c8; margin-top: 0px; padding-top: 0px;">ML content</h2>

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### <span style="color:#c8a2c8"><u>Phase 1</u> - Loading & Raw splitting</span>

# %% [markdown]
# #### <span style="color:#c8a2c8"><u>Phase 2</u> - Numerical Transformation</span>

# %% [markdown]
# #### <span style="color:#c8a2c8"><u>Phase 3</u> - Model Training</span>
